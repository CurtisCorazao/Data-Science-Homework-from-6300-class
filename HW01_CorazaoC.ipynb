# %%
#CodeBlock 1

import pandas as pd
import numpy as np

# %%
# CodeBlock 2
df_realestate = pd.read_csv('data/Real Estate Data.csv', index_col = 0, header = 0 )

# %%
# CodeBlock 3
df_realestate.head(5)
# Out:
#                     Type       Zoning Class  Lot Frontage  Lot Area Alley  \
# Id
# 1   2-STORY 1946 & NEWER  Resid Low Density          65.0      8450   NaN
# 2   1-STORY 1946 & NEWER  Resid Low Density          80.0      9600   NaN
# 3   2-STORY 1946 & NEWER  Resid Low Density          68.0     11250   NaN
# 4   2-STORY 1945 & OLDER  Resid Low Density          60.0      9550   NaN
# 5   2-STORY 1946 & NEWER  Resid Low Density          84.0     14260   NaN
#
#              Lot Shape Land Contour           Lot Config Land Slope  \
# Id
# 1              Regular        Level           Inside lot     Gentle
# 2              Regular        Level  Frontage on 2 sides     Gentle
# 3   Slightly irregular        Level           Inside lot     Gentle
# 4   Slightly irregular        Level           Corner lot     Gentle
# 5   Slightly irregular        Level  Frontage on 2 sides     Gentle
#
#              Nbhd  ... Open Porch Area Enclosed Porch Area  \
# Id                 ...
# ...

# %%
# CodeBlock 4
df_realestate.sample()
# Out:
#                       Type       Zoning Class  Lot Frontage  Lot Area Alley  \
# Id
# 1154  1-STORY 1945 & OLDER  Resid Med Density           NaN      5890   NaN
#
#      Lot Shape Land Contour  Lot Config Land Slope                    Nbhd  \
# Id
# 1154   Regular        Level  Corner lot     Gentle  Iowa DOT and Rail Road
#
#       ... Open Porch Area Enclosed Porch Area 3 Season Porch Area  \
# Id    ...
# 1154  ...               0                  96                   0
#
#       Screen Porch Area  Pool Area  Pool Qual     Fence  \
# Id
# 1154                  0          0    No Pool  No Fence
#
#                          Sale Type Sale Condition Sale Price
# Id
# 1154  Warranty Deed - Conventional    Normal Sale     120500
#
# [1 rows x 68 columns]

# %%
# CodeBlock 5
df_realestate.tail(2)
# Out:
#                       Type       Zoning Class  Lot Frontage  Lot Area Alley  \
# Id
# 1459  1-STORY 1946 & NEWER  Resid Low Density          68.0      9717   NaN
# 1460  1-STORY 1946 & NEWER  Resid Low Density          75.0      9937   NaN
#
#      Lot Shape Land Contour  Lot Config Land Slope        Nbhd  ...  \
# Id                                                              ...
# 1459   Regular        Level  Inside lot     Gentle  North Ames  ...
# 1460   Regular        Level  Inside lot     Gentle     Edwards  ...
#
#      Open Porch Area Enclosed Porch Area 3 Season Porch Area  \
# Id
# 1459               0                 112                   0
# 1460              68                   0                   0
#
#       Screen Porch Area  Pool Area  Pool Qual     Fence  \
# Id
# 1459                  0          0    No Pool  No Fence
# 1460                  0          0    No Pool  No Fence
#
#                          Sale Type Sale Condition Sale Price
# Id
# ...

# %%
# CodeBlock 6
df_realestate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1404 entries, 1 to 1460
# Data columns (total 68 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Type                      1404 non-null   object
#  1   Zoning Class              1404 non-null   object
#  2   Lot Frontage              1151 non-null   float64
#  3   Lot Area                  1404 non-null   int64
#  4   Alley                     84 non-null     object
#  5   Lot Shape                 1404 non-null   object
#  6   Land Contour              1404 non-null   object
#  7   Lot Config                1404 non-null   object
#  8   Land Slope                1404 non-null   object
#  9   Nbhd                      1404 non-null   object
#  10  Location Condition        1404 non-null   object
#  11  Bldg Type                 1404 non-null   object
#  12  House Style               1404 non-null   object
# ...

# %%
# CodeBlock 7

df_realestate = df_realestate.drop(['Zoning Class', 'Lot Shape', 'Lot Config', 'Land Slope', 'Bldg Type', 'House Style', 'Roof Style', 'Roof Material', 'Exterior Primary', 'Masonry/Veneer', 'Exterior Qual', 'Exterior Cond', 'Foundation', 'Basement Height', 'Basement Cond', 'Basement Exposure', 'Basement Finish', 'Heating Qual', 'CentralAir', 'Electrical', 'Functionality', 'Fireplce Qual', 'Garage Type', 'Garage Qual', 'Garage Cond', 'Paved Drive', 'Pool Qual', 'Fence', 'Sale Type', 'Year Remod Add'], axis = 1)

df_realestate.tail(2)
# Out:
#                       Type  Lot Frontage  Lot Area Alley Land Contour  \
# Id
# 1459  1-STORY 1946 & NEWER          68.0      9717   NaN        Level
# 1460  1-STORY 1946 & NEWER          75.0      9937   NaN        Level
#
#             Nbhd Location Condition  OvQual  Overall Cond  Built  ...  \
# Id                                                                ...
# 1459  North Ames             Normal       5             6   1950  ...
# 1460     Edwards             Normal       5             6   1965  ...
#
#       Garage Cars  Garage Area  Wood Deck Area  Open Porch Area  \
# Id
# 1459            1          240             366                0
# 1460            1          276             736               68
#
#       Enclosed Porch Area  3 Season Porch Area  Screen Porch Area  Pool Area  \
# Id
# 1459                  112                    0                  0          0
# 1460                    0                    0                  0          0
#
# ...

# %%
#CodeBlock 8

df_realestate = df_realestate.rename(columns = {'Type':'Dwelling Type', \
                                               'OvQual': 'Overall Quality',\
                                               'Nbhd' : 'Neighborhood',\
                                               'Built' : 'Year Built'})

df_realestate.tail(2)
# Out:
#              Dwelling Type  Lot Frontage  Lot Area Alley Land Contour  \
# Id
# 1459  1-STORY 1946 & NEWER          68.0      9717   NaN        Level
# 1460  1-STORY 1946 & NEWER          75.0      9937   NaN        Level
#
#      Neighborhood Location Condition  Overall Quality  Overall Cond  \
# Id
# 1459   North Ames             Normal                5             6
# 1460      Edwards             Normal                5             6
#
#       Year Built  ...  Garage Cars  Garage Area  Wood Deck Area  \
# Id                ...
# 1459        1950  ...            1          240             366
# 1460        1965  ...            1          276             736
#
#       Open Porch Area  Enclosed Porch Area  3 Season Porch Area  \
# Id
# 1459                0                  112                    0
# 1460               68                    0                    0
#
#       Screen Porch Area  Pool Area  Sale Condition  Sale Price
# Id
# ...

# %%
#CodeBlock 9

df_realestate.shape
# Out:
# (1404, 38)

# %%
#CodeBlock 10

df_realestate.groupby('Neighborhood')['Neighborhood'].count()
# Out:
# Neighborhood
# Bloomington Heights             6
# Bloomington Hts                11
# Bluestem                        2
# Briardale                      16
# Brookside                      49
# Clear Creek                    27
# College Creek                 150
# Crawford                       50
# Edwards                        89
# Gilbert                        79
# Iowa DOT and Rail Road         34
# Meadow Village                 10
# Mitchell                       48
# North Ames                    216
# Northpark Villa                 9
# Northridge                     41
# Northridge Heights             77
# Northwest Ames                 73
# Old Town                      103
# Sawyer                         74
# Sawyer West                    58
# Somerset                       86
# South & West of Iowa State     24
# Stone Brook                    25
# Timberland                     36
# Veenker                        11
# Name: Neighborhood, dtype: int64

# %%
#CodeBlock 11

df_realestate = df_realestate.replace('Bloomington Hts', 'Bloomington Heights')
df_realestate.groupby('Neighborhood')['Neighborhood'].count()
# Out:
# Neighborhood
# Bloomington Heights            17
# Bluestem                        2
# Briardale                      16
# Brookside                      49
# Clear Creek                    27
# College Creek                 150
# Crawford                       50
# Edwards                        89
# Gilbert                        79
# Iowa DOT and Rail Road         34
# Meadow Village                 10
# Mitchell                       48
# North Ames                    216
# Northpark Villa                 9
# Northridge                     41
# Northridge Heights             77
# Northwest Ames                 73
# Old Town                      103
# Sawyer                         74
# Sawyer West                    58
# Somerset                       86
# South & West of Iowa State     24
# Stone Brook                    25
# Timberland                     36
# Veenker                        11
# Name: Neighborhood, dtype: int64

# %%
# CodeBlock 12

df_realestate.groupby('Neighborhood')['Sale Price'].median()
# Out:
# Neighborhood
# Bloomington Heights           191000.0
# Bluestem                      137500.0
# Briardale                     106000.0
# Brookside                     128000.0
# Clear Creek                   200000.0
# College Creek                 197200.0
# Crawford                      208812.0
# Edwards                       120000.0
# Gilbert                       181000.0
# Iowa DOT and Rail Road        104750.0
# Meadow Village                106000.0
# Mitchell                      154750.0
# North Ames                    141000.0
# Northpark Villa               146000.0
# Northridge                    301500.0
# Northridge Heights            315000.0
# Northwest Ames                182900.0
# Old Town                      119900.0
# Sawyer                        135000.0
# Sawyer West                   179950.0
# Somerset                      225500.0
# South & West of Iowa State    139750.0
# Stone Brook                   278000.0
# Timberland                    233975.0
# ...

# %%
# CodeBlock 13

df_realestate.groupby('Dwelling Type')['Dwelling Type'].count()
# Out:
# Dwelling Type
# 1 STORY PUD               9
# 1-1/2 STORY ALL AGES    138
# 1-STORY 1945 & OLDER     62
# 1-STORY 1946 & NEWER    531
# 1-STORY PUD              78
# 2 FAMILY CONVERSION      28
# 2-1/2 STORY ALL AGES     15
# 2-STORY 1945 & OLDER     59
# 2-STORY 1946 & NEWER    298
# 2-STORY PUD              63
# DUPLEX                   46
# SPLIT FOYER              20
# SPLIT OR MULTI-LEVEL     57
# Name: Dwelling Type, dtype: int64

# %%
# CodeBlock 14

df_realestate = df_realestate.replace('1-STORY PUD', '1 STORY PUD')
df_realestate.groupby('Dwelling Type')['Dwelling Type'].count()
# Out:
# Dwelling Type
# 1 STORY PUD              87
# 1-1/2 STORY ALL AGES    138
# 1-STORY 1945 & OLDER     62
# 1-STORY 1946 & NEWER    531
# 2 FAMILY CONVERSION      28
# 2-1/2 STORY ALL AGES     15
# 2-STORY 1945 & OLDER     59
# 2-STORY 1946 & NEWER    298
# 2-STORY PUD              63
# DUPLEX                   46
# SPLIT FOYER              20
# SPLIT OR MULTI-LEVEL     57
# Name: Dwelling Type, dtype: int64

# %%
# CodeBlock 15

df_realestate.groupby(['Neighborhood', 'Dwelling Type'])['Sale Price'].median()
# Out:
# Neighborhood         Dwelling Type
# Bloomington Heights  1 STORY PUD             191500.0
#                      1-STORY 1946 & NEWER    159895.0
# Bluestem             2-STORY PUD             137500.0
# Briardale            2-STORY PUD             106000.0
# Brookside            1-1/2 STORY ALL AGES    132500.0
#                                                ...
# Timberland           SPLIT OR MULTI-LEVEL    181250.0
# Veenker              1 STORY PUD             270000.0
#                      1-STORY 1946 & NEWER    181500.0
#                      2-STORY 1946 & NEWER    294000.0
#                      SPLIT OR MULTI-LEVEL    190500.0
# Name: Sale Price, Length: 132, dtype: float64

# %%
# CodeBlock 16
df_re_pivot = df_realestate.pivot_table(index = 'Neighborhood', columns ='Land Contour', values='Sale Price' )

df_re_pivot
# Out:
# Land Contour                       Banked     Depression       Hillside  \
# Neighborhood
# Bloomington Heights                   NaN            NaN            NaN
# Bluestem                              NaN            NaN            NaN
# Briardale                             NaN            NaN            NaN
# Brookside                   165400.000000   39300.000000   82500.000000
# Clear Creek                 220250.000000  222666.666667  186500.000000
# College Creek               124900.000000  140666.666667  124000.000000
# Crawford                    198656.250000  224000.000000  221900.000000
# Edwards                     147035.714286   72950.000000   94750.000000
# Gilbert                     154500.000000            NaN  247640.625000
# Iowa DOT and Rail Road      108978.600000   94500.000000  102776.000000
# Meadow Village                        NaN            NaN            NaN
# Mitchell                    134000.000000  148200.000000  122625.000000
# ...

# %%
# CodeBlock 17
df_realestate['Garage Cars'].describe()
# Out:
# count    1404.000000
# mean        1.797721
# std         0.728482
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         2.000000
# max         4.000000
# Name: Garage Cars, dtype: float64

# %%
# CodeBlock 18
df_realestate['Garage Cars'].value_counts(normalize=True)
# Out:
# 2    0.574074
# 1    0.248575
# 3    0.128917
# 0    0.044872
# 4    0.003561
# Name: Garage Cars, dtype: float64

# %%
# CodeBlock 18
df_realestate[df_realestate ['Garage Cars'] <= 3].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1399 entries, 1 to 1460
# Data columns (total 38 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Dwelling Type             1399 non-null   object
#  1   Lot Frontage              1147 non-null   float64
#  2   Lot Area                  1399 non-null   int64
#  3   Alley                     83 non-null     object
#  4   Land Contour              1399 non-null   object
#  5   Neighborhood              1399 non-null   object
#  6   Location Condition        1399 non-null   object
#  7   Overall Quality           1399 non-null   int64
#  8   Overall Cond              1399 non-null   int64
#  9   Year Built                1399 non-null   int64
#  10  Masonry/Veneer Area       1391 non-null   float64
#  11  Basement Finished Area    1399 non-null   int64
#  12  Basement Unfinished Area  1399 non-null   int64
# ...

# %%
# CodeBlock 19
df_realestate = df_realestate.drop('Garage Area', axis = 1)
df_realestate.head(2)
# Out:
#            Dwelling Type  Lot Frontage  Lot Area Alley Land Contour  \
# Id
# 1   2-STORY 1946 & NEWER          65.0      8450   NaN        Level
# 2   1-STORY 1946 & NEWER          80.0      9600   NaN        Level
#
#      Neighborhood  Location Condition  Overall Quality  Overall Cond  \
# Id
# 1   College Creek              Normal                7             5
# 2         Veenker  Adjacent Feeder St                6             8
#
#     Year Built  ...   Garage Finish  Garage Cars  Wood Deck Area  \
# Id              ...
# 1         2003  ...  Rough Finished            2               0
# 2         1976  ...  Rough Finished            2             298
#
#     Open Porch Area  Enclosed Porch Area  3 Season Porch Area  \
# Id
# 1                61                    0                    0
# 2                 0                    0                    0
#
#     Screen Porch Area  Pool Area  Sale Condition  Sale Price
# Id
# ...

# %%
# CodeBlock 20
df_realestate['Sale Price'].describe()
# Out:
# count      1404.000000
# mean     183919.156695
# std       79236.046872
# min       34900.000000
# 25%      132500.000000
# 50%      165500.000000
# 75%      215050.000000
# max      755000.000000
# Name: Sale Price, dtype: float64

# %%
# CodeBlock 21
df_realestate[df_realestate ['Sale Price'] > 500000].shape
# Out:
# (9, 37)

# %%
# CodeBlock 22
df_realestate[df_realestate ['Sale Price'] > 500000].sort_values('Sale Price', ascending=False)
# Out:
#              Dwelling Type  Lot Frontage  Lot Area Alley Land Contour  \
# Id
# 692   2-STORY 1946 & NEWER         104.0     21535   NaN        Level
# 1183  2-STORY 1946 & NEWER         160.0     15623   NaN        Level
# 1170  2-STORY 1946 & NEWER         118.0     35760   NaN        Level
# 899   1-STORY 1946 & NEWER         100.0     12919   NaN        Level
# 804   2-STORY 1946 & NEWER         107.0     13891   NaN        Level
# 1047  2-STORY 1946 & NEWER          85.0     16056   NaN        Level
# 441   1-STORY 1946 & NEWER         105.0     15431   NaN        Level
# 770   2-STORY 1946 & NEWER          47.0     53504   NaN     Hillside
# 179   1-STORY 1946 & NEWER          63.0     17423   NaN        Level
#
#             Neighborhood Location Condition  Overall Quality  Overall Cond  \
# Id
# 692           Northridge             Normal               10             6
# 1183          Northridge             Normal               10             5
# ...

# %%
# CodeBlock 23
df_realestate[df_realestate ['Sale Price'] > 500000].sort_values('Sale Price', ascending=False)
# Out:
#              Dwelling Type  Lot Frontage  Lot Area Alley Land Contour  \
# Id
# 692   2-STORY 1946 & NEWER         104.0     21535   NaN        Level
# 1183  2-STORY 1946 & NEWER         160.0     15623   NaN        Level
# 1170  2-STORY 1946 & NEWER         118.0     35760   NaN        Level
# 899   1-STORY 1946 & NEWER         100.0     12919   NaN        Level
# 804   2-STORY 1946 & NEWER         107.0     13891   NaN        Level
# 1047  2-STORY 1946 & NEWER          85.0     16056   NaN        Level
# 441   1-STORY 1946 & NEWER         105.0     15431   NaN        Level
# 770   2-STORY 1946 & NEWER          47.0     53504   NaN     Hillside
# 179   1-STORY 1946 & NEWER          63.0     17423   NaN        Level
#
#             Neighborhood Location Condition  Overall Quality  Overall Cond  \
# Id
# 692           Northridge             Normal               10             6
# 1183          Northridge             Normal               10             5
# ...

# %%
# CodeBlock 24
df_re_over500k = df_realestate
df_re_over500k[df_re_over500k ['Sale Price'] > 500000].shape
# Out:
# (9, 37)

# %%
# CodeBlock 25
df_re_over500k.iloc[:,[0,5,36]].head()
# Out:
#            Dwelling Type   Neighborhood  Sale Price
# Id
# 1   2-STORY 1946 & NEWER  College Creek      208500
# 2   1-STORY 1946 & NEWER        Veenker      181500
# 3   2-STORY 1946 & NEWER  College Creek      223500
# 4   2-STORY 1945 & OLDER       Crawford      140000
# 5   2-STORY 1946 & NEWER     Northridge      250000

# %%
# CodeBlock 26
df_realestate[df_realestate ['Sale Price'] <= 500000].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1395 entries, 1 to 1460
# Data columns (total 37 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Dwelling Type             1395 non-null   object
#  1   Lot Frontage              1142 non-null   float64
#  2   Lot Area                  1395 non-null   int64
#  3   Alley                     84 non-null     object
#  4   Land Contour              1395 non-null   object
#  5   Neighborhood              1395 non-null   object
#  6   Location Condition        1395 non-null   object
#  7   Overall Quality           1395 non-null   int64
#  8   Overall Cond              1395 non-null   int64
#  9   Year Built                1395 non-null   int64
#  10  Masonry/Veneer Area       1387 non-null   float64
#  11  Basement Finished Area    1395 non-null   int64
#  12  Basement Unfinished Area  1395 non-null   int64
# ...

# %%
# CodeBlock 27

df_realestate.to_csv('data/Real Estate Data-Week2.csv')
