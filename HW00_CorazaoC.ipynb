# %% [markdown]
# HW00 Getting Started with Jupyter Notebooks
#
# By Curtis Corazao
#
# Import Libraries
#
# Import Data
#
# ## View Data

# %%
# CodeBlock 1

import numpy as np
import pandas as pd

# %%
# CodeBlock 2
df_weather = pd.read_csv('data/weather.csv', index_col = None, header = 0 )
# imported data from weather csv file
# Does not set the first column to the index
# and the top row as headers

# %%
# CodeBlock 3
df_weather.head(5)
# Out:
#        Date  MaxTemp         MaxTime  MinTemp         MinTime  cloudCover  \
# 0  3/1/2017    68.48   3/1/2017 5:00    51.69  2/28/2017 9:18        0.96
# 1  3/2/2017    69.75  3/1/2017 10:30    36.00   3/2/2017 5:00        0.53
# 2  3/3/2017    51.93  3/2/2017 21:49    30.87  3/2/2017 11:39        0.18
# 3  3/4/2017    44.03  3/3/2017 21:51    26.49  3/3/2017 14:06        0.14
# 4  3/5/2017    65.98  3/4/2017 21:24    27.40  3/4/2017 10:06        0.03
#
#    precipProbability  precipAmount      sunriseTime       sunsetTime  \
# 0               0.91        0.0184  2/28/2017 12:25  2/28/2017 23:46
# 1               1.00        0.2422   3/1/2017 12:24   3/1/2017 23:47
# 2               0.36        0.0028   3/2/2017 12:23   3/2/2017 23:48
# 3               0.70        0.0017   3/3/2017 12:21   3/3/2017 23:49
# 4               0.00        0.0000   3/4/2017 12:20   3/4/2017 23:50
#
#    windSpeed
# 0       6.20
# 1       9.69
# 2       4.63
# 3       2.26
# 4       4.69
